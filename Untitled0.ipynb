# %% [markdown]
# <a href="https://colab.research.google.com/github/smelendezz/Herrcomp-2021-2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
im=imread("MezclaColores.JPG")
imshow(im)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
im.shape
# Out:
# (768, 1024, 3)

# %%
im.dtype
# Out:
# dtype('uint8')

# %%
#muestra matriz de colores en el punto
im[500,800]
# Out:
# array([184,  13,  32], dtype=uint8)
